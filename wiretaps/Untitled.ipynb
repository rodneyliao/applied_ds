# %%
tap <- read.csv('fed_rep.csv')

# %%
names(tap)
# Out:
#  [1] "X"                                  "Jurisdiction"
#  [3] "A.O..Number"                        "Judge"
#  [5] "Attorney.General.or.Designee"       "Offense"
#  [7] "Type"                               "Location"
#  [9] "Application.Date"                   "Original.Order..Days."
# [11] "Number.of.Extensions"               "Total.Length..Days."
# [13] "Installation"                       "Number.of.Days.in.Operation"
# [15] "Avg..Intercepts.Per.Day"            "Number.of.Persons.Intercepts"
# [17] "Number.of.Intercepts"               "Number.of.Incriminating.Intercepts"
# [19] "cost"                               "Other.Than.Manpower.Cost...."
# [21] "Arrests"                            "Trials"
# [23] "Motions.Granted"                    "Motions.Denied"
# [25] "Motions.Pending"                    "Persons.Convicted"
# [27] "Cost.Related"                       "Results.Related"

# %%
hist(tap$Arrests)
# Out:
# Plot with title “Histogram of tap$Arrests”

# %%
hist(tap$cost)
# Out:
# Error in hist.default(tap$cost): 'x' must be numeric
# Traceback:
#
# 1. hist(tap$cost)
# 2. hist.default(tap$cost)
# 3. stop("'x' must be numeric")
