# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
import statsmodels.formula.api as smf
from sklearn.linear_model import Lasso
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
sns.set_context('talk')
sns.set_style('darkgrid')
sns.set_palette('colorblind')

# %%
import csv
import importlib

# %%
mfunds = pd.read_csv("MFData.csv")

# %%
mfunds.head()
# Out:
#        Date         VOO      VTSMX      SWTSX      VGTSX      VEIEX  VFITX  \
# 0  02-01-14  167.630005  46.259998  33.369999  16.510000  25.430000  11.14
# 1  03-01-14  167.479996  46.279999  33.380001  16.500000  25.260000  11.13
# 2  06-01-14  167.059998  46.130001  33.279999  16.480000  25.049999  11.15
# 3  07-01-14  168.100006  46.439999  33.500000  16.530001  25.080000  11.16
# 4  08-01-14  168.169998  46.459999  33.509998  16.520000  25.020000  11.12
#
#    VIPSX      VGSIX         TLT   IBMH
# 0  13.03  21.430000  102.169998  25.13
# 1  13.03  21.590000  102.169998  25.13
# 2  13.06  21.690001  102.599998  25.13
# 3  13.07  21.760000  102.860001  25.13
# 4  13.06  21.680000  102.580002  25.13

# %%
mfunds.plot()
