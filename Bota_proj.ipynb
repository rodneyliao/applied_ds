# %% [markdown]
# ## The following analysis is meant to explore where it pays to go college.
# ##### The data was collected by PayScale,Inc and the dataset was analyzed the Wall Street Journal with great emphasis on the Ivy League schools.
# ##### I am trying to use this dataset to help my little sister to figure out which major and university she should choose.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.formula.api as smf
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind
from scipy import stats
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import ParameterGrid
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import l1_min_c
from sklearn.metrics import roc_curve, auc
sns.set_context('talk')
sns.set_style('darkgrid')
sns.set_palette('colorblind')

# %% [markdown]
# ##### First let's see what the dataset represents

# %%
#data1 is the dataset of the salary according to undergraduate major
data1 = pd.read_csv('./major.csv')
data1.head()
# Out:
#      Undergraduate Major Starting Median Salary Mid-Career Median Salary  \
# 0             Accounting             $46,000.00               $77,100.00
# 1  Aerospace Engineering             $57,700.00              $101,000.00
# 2            Agriculture             $42,600.00               $71,900.00
# 3           Anthropology             $36,800.00               $61,500.00
# 4           Architecture             $41,600.00               $76,800.00
#
#    Percent change from Starting to Mid-Career Salary  \
# 0                                               67.6
# 1                                               75.0
# 2                                               68.8
# 3                                               67.1
# 4                                               84.6
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                        $42,200.00                        $56,100.00
# 1                        $64,300.00                        $82,100.00
# 2                        $36,300.00                        $52,100.00
# 3                        $33,800.00                        $45,500.00
# 4                        $50,600.00                        $62,200.00
#
#   Mid-Career 75th Percentile Salary Mid-Career 90th Percentile Salary
# 0                       $108,000.00                       $152,000.00
# 1                       $127,000.00                       $161,000.00
# 2                        $96,300.00                       $150,000.00
# 3                        $89,300.00                       $138,000.00
# 4                        $97,000.00                       $136,000.00

# %%
#data2 is the dataset of the salary according to the school and region: California, Northeast, Western, MidWestern and Southern
data2 = pd.read_csv('./salreg.csv')
data2.head()
# Out:
#                                 School Name      Region  \
# 0                       Stanford University  California
# 1  California Institute of Technology (CIT)  California
# 2                       Harvey Mudd College  California
# 3        University of California, Berkeley  California
# 4                        Occidental College  California
#
#   Starting Median Salary Mid-Career Median Salary  \
# 0             $70,400.00              $129,000.00
# 1             $75,500.00              $123,000.00
# 2             $71,800.00              $122,000.00
# 3             $59,900.00              $112,000.00
# 4             $51,900.00              $105,000.00
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                        $68,400.00                        $93,100.00
# 1                               NaN                       $104,000.00
# 2                               NaN                        $96,000.00
# 3                        $59,500.00                        $81,000.00
# 4                               NaN                        $54,800.00
#
#   Mid-Career 75th Percentile Salary Mid-Career 90th Percentile Salary
# 0                       $184,000.00                       $257,000.00
# 1                       $161,000.00                               NaN
# 2                       $180,000.00                               NaN
# 3                       $149,000.00                       $201,000.00
# 4                       $157,000.00                               NaN

# %%
#data3 is the dataset of the salary according to the school and type: Engineering, Liberal Arts and Party
data3 = pd.read_csv('./salcollege.csv')
data3.head()
# Out:
#                                     School Name  School Type  \
# 0   Massachusetts Institute of Technology (MIT)  Engineering
# 1      California Institute of Technology (CIT)  Engineering
# 2                           Harvey Mudd College  Engineering
# 3  Polytechnic University of New York, Brooklyn  Engineering
# 4                                  Cooper Union  Engineering
#
#   Starting Median Salary Mid-Career Median Salary  \
# 0             $72,200.00              $126,000.00
# 1             $75,500.00              $123,000.00
# 2             $71,800.00              $122,000.00
# 3             $62,400.00              $114,000.00
# 4             $62,200.00              $114,000.00
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                        $76,800.00                        $99,200.00
# 1                               NaN                       $104,000.00
# 2                               NaN                        $96,000.00
# 3                        $66,800.00                        $94,300.00
# 4                               NaN                        $80,200.00
#
#   Mid-Career 75th Percentile Salary Mid-Career 90th Percentile Salary
# 0                       $168,000.00                       $220,000.00
# 1                       $161,000.00                               NaN
# 2                       $180,000.00                               NaN
# 3                       $143,000.00                       $190,000.00
# 4                       $142,000.00                               NaN

# %%
#I want to rename the column names for easier coding
data1.columns = ['major','start_med_sal','mid_sal','change_startmid','mid_p10','mid_p25','mid_p75','mid_p90']
data2.columns = ['school', 'region', 'start_med_sal','mid_sal', 'mid_p10', 'mid_p25','mid_p75','mid_p90']
data3.columns = ['school', 'type', 'start_med_sal','mid_sal', 'mid_p10', 'mid_p25','mid_p75','mid_p90']
data1.head()
# Out:
#                    major start_med_sal      mid_sal  change_startmid  \
# 0             Accounting    $46,000.00   $77,100.00             67.6
# 1  Aerospace Engineering    $57,700.00  $101,000.00             75.0
# 2            Agriculture    $42,600.00   $71,900.00             68.8
# 3           Anthropology    $36,800.00   $61,500.00             67.1
# 4           Architecture    $41,600.00   $76,800.00             84.6
#
#       mid_p10     mid_p25      mid_p75      mid_p90
# 0  $42,200.00  $56,100.00  $108,000.00  $152,000.00
# 1  $64,300.00  $82,100.00  $127,000.00  $161,000.00
# 2  $36,300.00  $52,100.00   $96,300.00  $150,000.00
# 3  $33,800.00  $45,500.00   $89,300.00  $138,000.00
# 4  $50,600.00  $62,200.00   $97,000.00  $136,000.00

# %%
data1.dtypes
# Out:
# major               object
# start_med_sal       object
# mid_sal             object
# change_startmid    float64
# mid_p10             object
# mid_p25             object
# mid_p75             object
# mid_p90             object
# dtype: object

# %%
# want to change from $ to numbers
def replace(data, x):
    data[x] = data[x].str.replace("$","")
    data[x] = data[x].str.replace(",","")
    data[x] = pd.to_numeric(data[x])
    
dollar_cols = ['start_med_sal','mid_sal','mid_p10','mid_p25','mid_p75','mid_p90']

for x in dollar_cols:
    replace(data1, x)
    replace(data2, x)
    replace(data3, x)
    
data1.head()
# Out:
#                    major  start_med_sal   mid_sal  change_startmid  mid_p10  \
# 0             Accounting        46000.0   77100.0             67.6  42200.0
# 1  Aerospace Engineering        57700.0  101000.0             75.0  64300.0
# 2            Agriculture        42600.0   71900.0             68.8  36300.0
# 3           Anthropology        36800.0   61500.0             67.1  33800.0
# 4           Architecture        41600.0   76800.0             84.6  50600.0
#
#    mid_p25   mid_p75   mid_p90
# 0  56100.0  108000.0  152000.0
# 1  82100.0  127000.0  161000.0
# 2  52100.0   96300.0  150000.0
# 3  45500.0   89300.0  138000.0
# 4  62200.0   97000.0  136000.0

# %%
data1.dtypes
# Out:
# major               object
# start_med_sal      float64
# mid_sal            float64
# change_startmid    float64
# mid_p10            float64
# mid_p25            float64
# mid_p75            float64
# mid_p90            float64
# dtype: object

# %%
# to see how much of data pts are missing in major data
data1.isnull().sum()
# Out:
# major              0
# start_med_sal      0
# mid_sal            0
# change_startmid    0
# mid_p10            0
# mid_p25            0
# mid_p75            0
# mid_p90            0
# dtype: int64

# %%
# to see how much of data pts are missing in school data
data2.isnull().sum()
# Out:
# school            0
# region            0
# start_med_sal     0
# mid_sal           0
# mid_p10          47
# mid_p25           0
# mid_p75           0
# mid_p90          47
# dtype: int64

# %%
(data2.isnull().sum()/len(data2)).plot(kind='bar')

# %%
(data3.isnull().sum()/len(data3)).plot(kind='bar')

# %% [markdown]
# ##### It is obvious that the data is missing only for mid-career 10th and 90th percentile, let's see if we can interpolate this data based on the region and nearby university and type later when we merge the datasets 2 and 3 (because they have common variable = school).

# %%
#to show that there are no duplicates for majors
data1['major'].value_counts()
# Out:
# Computer Science                        1
# International Relations                 1
# Information Technology (IT)             1
# Nursing                                 1
# Biology                                 1
# Forestry                                1
# Psychology                              1
# Accounting                              1
# Graphic Design                          1
# Chemistry                               1
# English                                 1
# Economics                               1
# Anthropology                            1
# History                                 1
# Chemical Engineering                    1
# Art History                             1
# Finance                                 1
# Sociology                               1
# Film                                    1
# Computer Engineering                    1
# Industrial Engineering                  1
# Construction                            1
# Communications                          1
# Architecture                            1
# Interior Design                         1
# Electrical Engineering                  1
# Drama                                   1
# Music                                   1
# Math                                    1
# Agriculture                             1
# Criminal Justice                        1
# Philosophy                              1
# Civil Engineering                       1
# Hospitality & Tourism                   1
# Mechanical Engineering                  1
# Aerospace Engineering                   1
# Nutrition                               1
# Management Information Systems (MIS)    1
# Education                               1
# Marketing                               1
# Health Care Administration              1
# Geology                                 1
# Religion                                1
# Geography                               1
# Physician Assistant                     1
# Spanish                                 1
# Business Management                     1
# Physics                                 1
# Journalism                              1
# Political Science                       1
# Name: major, dtype: int64

# %%
# to see what major has the highest fresh out of college salary
sorted_d1 = data1.sort_values('start_med_sal', ascending=False)
sorted_d1.iloc[:,0:2].head(20)
# Out:
#                                    major  start_med_sal
# 43                   Physician Assistant        74300.0
# 8                   Chemical Engineering        63200.0
# 12                  Computer Engineering        61400.0
# 19                Electrical Engineering        60900.0
# 38                Mechanical Engineering        57900.0
# 1                  Aerospace Engineering        57700.0
# 30                Industrial Engineering        57700.0
# 13                      Computer Science        55900.0
# 40                               Nursing        54200.0
# 10                     Civil Engineering        53900.0
# 14                          Construction        53700.0
# 44                               Physics        50300.0
# 17                             Economics        50100.0
# 35  Management Information Systems (MIS)        49200.0
# 31           Information Technology (IT)        49100.0
# 22                               Finance        47900.0
# 0                             Accounting        46000.0
# 37                                  Math        45400.0
# 25                               Geology        43500.0
# 7                    Business Management        43000.0

# %% [markdown]
# #### This might suggest that if you choose to be any type of Engineer you end up in the top 10 earners.

# %%
x = data1['major'].dropna()
y = data1['start_med_sal'][data1.start_med_sal!=0].dropna()
z = data1['mid_sal'][data1.mid_sal!=0].dropna()
p = data1['change_startmid'].dropna()

p = sns.pairplot(pd.DataFrame(list(zip(x,y, np.log(z), np.log10(p))), columns=['major', 'start_med_sal_x', 'mid_sal_x', 'change_startmid']), palette="Set2" )

# %%
# to see what uni grads have the highest fresh out of college salary
sorted_d2 = data2.sort_values('start_med_sal', ascending=False)
sorted_d2.iloc[:,0:3].head(20)
# Out:
#                                            school        region  start_med_sal
# 1        California Institute of Technology (CIT)    California        75500.0
# 222   Massachusetts Institute of Technology (MIT)  Northeastern        72200.0
# 2                             Harvey Mudd College    California        71800.0
# 0                             Stanford University    California        70400.0
# 221                          Princeton University  Northeastern        66500.0
# 141                               Rice University      Southern        64000.0
# 224                            Harvard University  Northeastern        63400.0
# 226  Polytechnic University of New York, Brooklyn  Northeastern        62400.0
# 227                                  Cooper Union  Northeastern        62200.0
# 229              Carnegie Mellon University (CMU)  Northeastern        61800.0
# 230        Rensselaer Polytechnic Institute (RPI)  Northeastern        61100.0
# 228         Worcester Polytechnic Institute (WPI)  Northeastern        61000.0
# 225                    University of Pennsylvania  Northeastern        60900.0
# 240               Stevens Institute of Technology  Northeastern        60600.0
# 231                            Cornell University  Northeastern        60300.0
# 3              University of California, Berkeley    California        59900.0
# 235                           Columbia University  Northeastern        59400.0
# 241                             Lehigh University  Northeastern        59200.0
# 223                               Yale University  Northeastern        59100.0
# 143                               Duke University      Southern        58900.0

# %% [markdown]
# #### This might suggest that if you better go to the Northeastern region.
#
# #### Now let's look at the salary depending on the type of school.

# %%
#to define the starting median salary for different type of schools
engSalaries = data3["start_med_sal"][data3["type"] == "Engineering"]
libSalaries = data3["start_med_sal"][data3["type"] == "Liberal Arts"]
partySalaries = data3["start_med_sal"][data3["type"] == "Party"]
ivySalaries = data3["start_med_sal"][data3["type"] == "Ivy League"]
stateSalaries = data3["start_med_sal"][data3["type"] == "State"]

print("Mean (starting) salary for Ivy League Schools:")
print(ivySalaries.mean())


print("Mean (starting) salary for Engineering Schools:")
print(engSalaries.mean())

print("Mean (starting) salary for State Schools:")
print(stateSalaries.mean())

print("Mean (starting) salary for Liberal Arts Schools")
print(libSalaries.mean())

print("Mean (starting) salary for Party Schools")
print(partySalaries.mean())
# Out:
# Mean (starting) salary for Ivy League Schools:
# 60475.0
# Mean (starting) salary for Engineering Schools:
# 59057.89473684211
# Mean (starting) salary for State Schools:
# 44126.28571428572
# Mean (starting) salary for Liberal Arts Schools
# 45746.8085106383
# Mean (starting) salary for Party Schools
# 45715.0

# %% [markdown]
# #### Let's analyze the starting median salary range for Engineering and Ivy League School.

# %%
plt.style.use('ggplot')

plt.hist(ivySalaries, alpha=0.3, label='Ivy League')
plt.hist(engSalaries, alpha=0.4,  label='Engineering')

plt.legend(loc='upper right')

plt.title("Salaries by type")
plt.xlabel('Starting Median Salary')
# Out:
# Text(0.5, 0, 'Starting Median Salary')

# %% [markdown]
# #### need to analyze this relationship more

# %%
#analyze the relationship b/n starting median salary and mid-salary for dataset 1
f, ax = plt.subplots(figsize=(5.5, 5.5))
data1.plot.scatter('start_med_sal','mid_sal',alpha=0.90,ax=ax)

# %%
#analyze the relationship b/n starting median salary and mid-salary for dataset 2
f, ax = plt.subplots(figsize=(5.5, 5.5))
data2.plot.scatter('start_med_sal','mid_sal',alpha=0.60,ax=ax)

# %%
f, ax = plt.subplots(figsize=(6.5, 6.5))
data3.plot.scatter('start_med_sal','mid_sal',alpha=0.60,ax=ax)

# %% [markdown]
# ### Merging two datasets

# %%
# because data2 and data3 have a common column school i am able to merge these datasets
new_dataset=data2.merge(data3, left_on='school' , right_on='school')

# %%
new_dataset.head()
# Out:
#                                      school      region  start_med_sal_x  \
# 0  California Institute of Technology (CIT)  California          75500.0
# 1                       Harvey Mudd College  California          71800.0
# 2        University of California, Berkeley  California          59900.0
# 3                        Occidental College  California          51900.0
# 4                  Cal Poly San Luis Obispo  California          57200.0
#
#    mid_sal_x  mid_p10_x  mid_p25_x  mid_p75_x  mid_p90_x          type  \
# 0   123000.0        NaN   104000.0   161000.0        NaN   Engineering
# 1   122000.0        NaN    96000.0   180000.0        NaN   Engineering
# 2   112000.0    59500.0    81000.0   149000.0   201000.0         State
# 3   105000.0        NaN    54800.0   157000.0        NaN  Liberal Arts
# 4   101000.0    55000.0    74700.0   133000.0   178000.0         State
#
#    start_med_sal_y  mid_sal_y  mid_p10_y  mid_p25_y  mid_p75_y  mid_p90_y
# 0          75500.0   123000.0        NaN   104000.0   161000.0        NaN
# 1          71800.0   122000.0        NaN    96000.0   180000.0        NaN
# 2          59900.0   112000.0    59500.0    81000.0   149000.0   201000.0
# 3          51900.0   105000.0        NaN    54800.0   157000.0        NaN
# 4          57200.0   101000.0    55000.0    74700.0   133000.0   178000.0

# %%
CAsal = new_dataset["start_med_sal_x"][new_dataset["region"] == "California"]
NEsal = new_dataset["start_med_sal_x"][new_dataset["region"] == "Northeastern"]
Wsal = new_dataset["start_med_sal_x"][new_dataset["region"] == "Western"]
MWsal = new_dataset["start_med_sal_x"][new_dataset["region"] == "Midwestern"]
Ssal = new_dataset["start_med_sal_x"][new_dataset["region"] == "Southern"]

# %%
plt.style.use('ggplot')
plt.axes.titlesize : 24
plt.axes.labelsize : 20


plt.hist(CAsal, alpha=0.7, label='California')
plt.hist(NEsal, alpha=0.4,  label='Northeastern')
plt.hist(Wsal, alpha=0.8,  label='Western')
plt.hist(MWsal, alpha=0.4,  label='Midwestern')
plt.hist(Ssal, alpha=0.4,  label='Southern')


plt.legend(loc='upper right')

plt.title("Salaries by type")
plt.xlabel('Starting Median Salary')
# Out:
# Text(0.5, 0, 'Starting Median Salary')

# %%
mid_p10_test = new_dataset["mid_p10_x"][new_dataset["region"] == "California"]
print("Mean mid-career 10 percentile for California Schools:")
print(mid_p10_test.mean())
# Out:
# Mean mid-career 10 percentile for California Schools:
# 46871.42857142857

# %%
mid_p10_test2 = new_dataset["mid_p10_y"][new_dataset["region"] == "California"]
print("Mean mid-career 10 percentile for California Schools:")
print(mid_p10_test2.median())
# Out:
# Mean mid-career 10 percentile for California Schools:
# 46450.0

# %%
#lets look at correlation
corr = new_dataset.corr()
corr.style.background_gradient(cmap='RdBu_r', axis=None) # 'coolwarm', RdBu_r', & 'BrBG' good color maps
# Out:
# <style  type="text/css" >
#     #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row0_col0 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row0_col1 {
#             background-color:  #f2a17f;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row0_col2 {
#             background-color:  #f5ac8b;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row0_col3 {
#             background-color:  #e8896c;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row0_col4 {
#             background-color:  #b3d6e8;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row0_col5 {
#             background-color:  #3b88be;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row0_col6 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row0_col7 {
#             background-color:  #f2a17f;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row0_col8 {
#             background-color:  #f6b191;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row0_col9 {
#             background-color:  #e8896c;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row0_col10 {
#             background-color:  #b3d6e8;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row0_col11 {
#             background-color:  #4291c2;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row1_col0 {
#             background-color:  #f2a17f;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row1_col1 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row1_col2 {
#             background-color:  #f9c2a7;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row1_col3 {
#             background-color:  #dc6e57;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row1_col4 {
#             background-color:  #dd7059;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row1_col5 {
#             background-color:  #fcd5bf;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row1_col6 {
#             background-color:  #f2a17f;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row1_col7 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row1_col8 {
#             background-color:  #f7b799;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row1_col9 {
#             background-color:  #dc6e57;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row1_col10 {
#             background-color:  #dd7059;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row1_col11 {
#             background-color:  #fbccb4;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row2_col0 {
#             background-color:  #f5ac8b;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row2_col1 {
#             background-color:  #f9c2a7;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row2_col2 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row2_col3 {
#             background-color:  #c94741;
#             color:  #f1f1f1;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row2_col4 {
#             background-color:  #a2cde3;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row2_col5 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row2_col6 {
#             background-color:  #f5ac8b;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row2_col7 {
#             background-color:  #f9c2a7;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row2_col8 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row2_col9 {
#             background-color:  #c94741;
#             color:  #f1f1f1;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row2_col10 {
#             background-color:  #a2cde3;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row2_col11 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row3_col0 {
#             background-color:  #e8896c;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row3_col1 {
#             background-color:  #dc6e57;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row3_col2 {
#             background-color:  #c94741;
#             color:  #f1f1f1;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row3_col3 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row3_col4 {
#             background-color:  #bddbea;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row3_col5 {
#             background-color:  #75b2d4;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row3_col6 {
#             background-color:  #e8896c;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row3_col7 {
#             background-color:  #dc6e57;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row3_col8 {
#             background-color:  #c6413e;
#             color:  #f1f1f1;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row3_col9 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row3_col10 {
#             background-color:  #bddbea;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row3_col11 {
#             background-color:  #90c4dd;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row4_col0 {
#             background-color:  #b3d6e8;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row4_col1 {
#             background-color:  #dd7059;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row4_col2 {
#             background-color:  #a2cde3;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row4_col3 {
#             background-color:  #bddbea;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row4_col4 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row4_col5 {
#             background-color:  #cb4942;
#             color:  #f1f1f1;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row4_col6 {
#             background-color:  #b3d6e8;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row4_col7 {
#             background-color:  #dd7059;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row4_col8 {
#             background-color:  #b6d7e8;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row4_col9 {
#             background-color:  #bddbea;
#             color:  #000000;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row4_col10 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_c78ce002_616d_11e9_a489_88e9fe6bd1f2row4_col11 {
#             background-color:  #c84440;
#             color:  #f

# %% [markdown]
# #### Let's look at relationships in the new merged dataset

# %%
x = new_dataset['school'].dropna()
y = new_dataset['region'].dropna()
z = new_dataset['start_med_sal_x'][new_dataset.start_med_sal_x!=0].dropna()
p = new_dataset['mid_sal_x'][new_dataset.mid_sal_x!=0].dropna()
t = new_dataset['type'].dropna()
start_salary = new_dataset['start_med_sal_y']

p = sns.pairplot(pd.DataFrame(list(zip(x, y, np.log(z), np.log10(p), t, start_salary)), columns=['school','region', 'start_med_sal_x', 'mid_sal_x', 'type', 'start_med_sal_y']),hue="type", palette="Set2" )
